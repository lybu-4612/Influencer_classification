# %%
import numpy as np
import cv2 as cv
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # (1) Preprocessing: Detect face and eyes
# When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>
# Now how do you detect face and eyes?

# %%
img= cv.imread(r"\Users\amarn\OneDrive\SportsPersonClassifier\model\text_images\gettyimages-140021698-612x612.jpg")
img.shape
# Out:
# (612, 408, 3)

# %%
plt.imshow(img)

# %%
gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
gray.shape
# Out:
# (612, 408)

# %%
gray
# Out:
# array([[154, 154, 154, ..., 153, 153, 153],
#        [154, 154, 154, ..., 153, 153, 153],
#        [154, 154, 154, ..., 154, 154, 154],
#        ...,
#        [ 23,  23,  23, ...,  12,  12,  12],
#        [ 23,  23,  23, ...,  11,  11,  11],
#        [ 23,  23,  23, ...,   9,   9,   9]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 84,  90, 270, 270]])

# %%
(x,y,w,h)= faces[0]
x,y,w,h
# Out:
# (84, 90, 270, 270)

# %%
face_image= cv.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
plt.imshow(face_image)

# %%
cv.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# # (2) Preprocessing: Crop the facial region of the image

# %%
# %matplotlib inline
plt.imshow(roi_color,cmap="gray")

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (270, 270, 3)

# %% [markdown]
# # (3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region
# Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv.imread(image_path)
    gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image= get_cropped_image_if_2_eyes(r"\Users\amarn\OneDrive\SportsPersonClassifier\model\text_images\gettyimages-140021698-612x612.jpg")
plt.imshow(original_image)

# %% [markdown]
# In below image face is not very clear and it doesn't have two eyes clearly visible

# %%
cropped_image=cv.imread(r"C:\Users\amarn\OneDrive\SportsPersonClassifier\model\text_images\gettyimages-1200621079-612x612.jpg")
plt.imshow(cropped_image)

# %%
croped_but_no_eye= get_cropped_image_if_2_eyes(r"C:\Users\amarn\OneDrive\SportsPersonClassifier\model\text_images\gettyimages-1200621079-612x612.jpg")
croped_but_no_eye

# %% [markdown]
# Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Christian_Bale',
#  './dataset/cristiano_ronaldo',
#  './dataset/Elon_musk',
#  './dataset/Malala',
#  './dataset/Yuvaraj_singh']

# %% [markdown]
# Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Christian_Bale
# Generating cropped images in folder:  ./dataset/cropped/cristiano_ronaldo
# Generating cropped images in folder:  ./dataset/cropped/Elon_musk
# Generating cropped images in folder:  ./dataset/cropped/Malala
# Generating cropped images in folder:  ./dataset/cropped/Yuvaraj_singh

# %% [markdown]
# Now you should have cropped folder under datasets folder that contains cropped images
# Manually examine cropped folder and delete any unwanted images

# %%
import numpy as np
import pywt
import cv2 as cv    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv.cvtColor( imArray,cv.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# # Now you should have cropped folder under datasets folder that contains cropped images
# Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Christian_Bale': ['./dataset/cropped/Christian_Bale\\Christian_Bale1.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale10.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale100.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale101.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale102.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale103.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale104.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale105.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale106.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale107.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale108.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale109.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale11.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale110.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale111.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale112.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale113.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale114.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale115.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale116.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale117.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale118.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale119.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale12.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale120.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale121.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale122.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale123.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale124.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale125.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale126.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale127.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale128.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale129.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale13.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale130.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale131.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale132.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale133.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale134.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale135.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale136.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale137.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale138.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale139.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale14.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale15.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale16.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale17.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale18.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale19.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale2.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale20.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale21.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale22.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale23.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale24.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale25.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale26.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale27.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale28.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale29.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale3.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale30.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale31.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale32.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale33.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale34.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale35.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale36.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale37.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale38.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale39.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale4.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale40.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale41.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale42.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale43.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale44.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale45.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale46.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale47.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale48.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale49.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale5.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale50.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale51.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale52.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale53.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale54.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale55.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale56.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale57.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale58.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale59.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale6.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale60.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale61.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale62.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale63.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale64.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale65.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale66.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale67.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale68.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale69.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale7.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale70.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale71.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale72.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale73.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale74.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale75.png',
#   './dataset/cropped/Christian_Bale\\Christian_Bale76.png',
#   './dataset/cropped/Christian_Bale\\Christian_B
#   './dataset/cropped/Elon_musk\\Elon_musk52.png',
#   './dataset/cropped/Elon_musk\\Elon_musk53.png',
#   './dataset/cropped/Elon_musk\\Elon_musk54.png',
#   './dataset/cropped/Elon_musk\\Elon_musk55.png',
#   './dataset/cropped/Elon_musk\\Elon_musk56.png',
#   './dataset/cropped/Elon_musk\\Elon_musk57.png',
#   './dataset/cropped/Elon_musk\\Elon_musk58.png',
#   './dataset/cropped/Elon_musk\\Elon_musk59.png',
#   './dataset/cropped/Elon_musk\\Elon_musk6.png',
#   './dataset/cropped/Elon_musk\\Elon_musk60.png',
#   './dataset/cropped/Elon_musk\\Elon_musk61.png',
#   './dataset/cropped/Elon_musk\\Elon_musk62.png',
#   './dataset/cropped/Elon_musk\\Elon_musk63.png',
#   './dataset/cropped/Elon_musk\\Elon_musk64.png',
#   './dataset/cropped/Elon_musk\\Elon_musk65.png',
#   './dataset/cropped/Elon_musk\\Elon_musk66.png',
#   './dataset/cropped/Elon_musk\\Elon_musk67.png',
#   './dataset/cropped/Elon_musk\\Elon_musk7.png',
#   './dataset/cropped/Elon_musk\\Elon_musk8.png',
#   './dataset/cropped/Elon_musk\\Elon_musk9.png'],
#  'Malala': ['./dataset/cropped/Malala\\Malala1.png',
#   './dataset/cropped/Malala\\Malala10.png',
#   './dataset/cropped/Malala\\Malala11.png',
#   './dataset/cropped/Malala\\Malala12.png',
#   './dataset/cropped/Malala\\Malala13.png',
#   './dataset/cropped/Malala\\Malala14.png',
#   './dataset/cropped/Malala\\Malala15.png',
#   './dataset/cropped/Malala\\Malala16.png',
#   './dataset/cropped/Malala\\Malala17.png',
#   './dataset/cropped/Malala\\Malala18.png',
#   './dataset/cropped/Malala\\Malala19.png',
#   './dataset/cropped/Malala\\Malala2.png',
#   './dataset/cropped/Malala\\Malala20.png',
#   './dataset/cropped/Malala\\Malala21.png',
#   './dataset/cropped/Malala\\Malala22.png',
#   './dataset/cropped/Malala\\Malala23.png',
#   './dataset/cropped/Malala\\Malala24.png',
#   './dataset/cropped/Malala\\Malala25.png',
#   './dataset/cropped/Malala\\Malala26.png',
#   './dataset/cropped/Malala\\Malala27.png',
#   './dataset/cropped/Malala\\Malala28.png',
#   './dataset/cropped/Malala\\Malala29.png',
#   './dataset/cropped/Malala\\Malala3.png',
#   './dataset/cropped/Malala\\Malala30.png',
#   './dataset/cropped/Malala\\Malala31.png',
#   './dataset/cropped/Malala\\Malala32.png',
#   './dataset/cropped/Malala\\Malala33.png',
#   './dataset/cropped/Malala\\Malala34.png',
#   './dataset/cropped/Malala\\Malala35.png',
#   './dataset/cropped/Malala\\Malala36.png',
#   './dataset/cropped/Malala\\Malala37.png',
#   './dataset/cropped/Malala\\Malala38.png',
#   './dataset/cropped/Malala\\Malala39.png',
#   './dataset/cropped/Malala\\Malala4.png',
#   './dataset/cropped/Malala\\Malala40.png',
#   './dataset/cropped/Malala\\Malala41.png',
#   './dataset/cropped/Malala\\Malala42.png',
#   './dataset/cropped/Malala\\Malala43.png',
#   './dataset/cropped/Malala\\Malala44.png',
#   './dataset/cropped/Malala\\Malala45.png',
#   './dataset/cropped/Malala\\Malala46.png',
#   './dataset/cropped/Malala\\Malala47.png',
#   './dataset/cropped/Malala\\Malala48.png',
#   './dataset/cropped/Malala\\Malala49.png',
#   './dataset/cropped/Malala\\Malala5.png',
#   './dataset/cropped/Malala\\Malala50.png',
#   './dataset/cropped/Malala\\Malala51.png',
#   './dataset/cropped/Malala\\Malala52.png',
#   './dataset/cropped/Malala\\Malala53.png',
#   './dataset/cropped/Malala\\Malala54.png',
#   './dataset/cropped/Malala\\Malala55.png',
#   './dataset/cropped/Malala\\Malala56.png',
#   './dataset/cropped/Malala\\Malala57.png',
#   './dataset/cropped/Malala\\Malala58.png',
#   './dataset/cropped/Malala\\Malala59.png',
#   './dataset/cropped/Malala\\Malala6.png',
#   './dataset/cropped/Malala\\Malala60.png',
#   './dataset/cropped/Malala\\Malala61.png',
#   './dataset/cropped/Malala\\Malala62.png',
#   './dataset/cropped/Malala\\Malala63.png',
#   './dataset/cropped/Malala\\Malala64.png',
#   './dataset/cropped/Malala\\Malala65.png',
#   './dataset/cropped/Malala\\Malala66.png',
#   './dataset/cropped/Malala\\Malala67.png',
#   './dataset/cropped/Malala\\Malala68.png',
#   './dataset/cropped/Malala\\Malala69.png',
#   './dataset/cropped/Malala\\Malala7.png',
#   './dataset/cropped/Malala\\Malala70.png',
#   './dataset/cropped/Malala\\Malala71.png',
#   './dataset/cropped/Malala\\Malala72.png',
#   './dataset/cropped/Malala\\Malala73.png',
#   './dataset/cropped/Malala\\Malala74.png',
#   './dataset/cropped/Malala\\Malala75.png',
#   './dataset/cropped/Malala\\Malala76.png',
#   './dataset/cropped/Malala\\Malala77.png',
#   './dataset/cropped/Malala\\Malala78.png',
#   './dataset/cropped/Malala\\Malala79.png',
#   './dataset/cropped/Malala\\Malala8.png',
#   './dataset/cropped/Malala\\Malala80.png',
#   './dataset/cropped/Malala\\Malala81.png',
#   './dataset/cropped/Malala\\Malala82.png',
#   './dataset/cropped/Malala\\Malala83.png',
#   './dataset/cropped/Malala\\Malala84.png',
#   './dataset/cropped/Malala\\Malala85.png',
#   './dataset/cropped/Malala\\Malala86.png',
#   './dataset/cropped/Malala\\Malala87.png',
#   './dataset/cropped/Malala\\Malala88.png',
#   './dataset/cropped/Malala\\Malala89.png',
#   './dataset/cropped/Malala\\Malala9.png'],
#  'Yuvaraj_singh': ['./dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh1.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh10.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh11.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh12.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh13.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh14.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh15.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh16.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh17.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh18.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh19.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh2.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh20.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh21.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh22.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh23.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh24.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh25.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh26.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh27.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh28.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh29.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh3.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh30.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh31.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh32.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh33.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh34.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh35.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh4.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh5.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh6.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh7.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh8.png',
#   './dataset/cropped/Yuvaraj_singh\\Yuvaraj_singh9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Christian_Bale': 0,
#  'cristiano_ronaldo': 1,
#  'Elon_musk': 2,
#  'Malala': 3,
#  'Yuvaraj_singh': 4}

# %% [markdown]
# # Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv.imread(training_image)
        scalled_raw_img = cv.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[  1],
#        [  1],
#        [  1],
#        ...,
#        [216],
#        [215],
#        [114]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (364, 4096)

# %% [markdown]
# # Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8351648351648352

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.92      0.84        37
#            1       1.00      0.50      0.67        10
#            2       0.71      0.77      0.74        13
#            3       0.96      0.96      0.96        24
#            4       1.00      0.57      0.73         7
#
#     accuracy                           0.84        91
#    macro avg       0.89      0.74      0.79        91
# weighted avg       0.86      0.84      0.83        91

# %% [markdown]
# # Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.893737
# 1        random_forest    0.747071
# 2  logistic_regression    0.886263
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8901098901098901

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.7802197802197802

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8901098901098901

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[34,  0,  1,  2,  0],
#        [ 2,  8,  0,  0,  0],
#        [ 1,  1, 11,  0,  0],
#        [ 1,  0,  0, 23,  0],
#        [ 2,  0,  0,  0,  5]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %% [markdown]
# # Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %% [markdown]
# # Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
